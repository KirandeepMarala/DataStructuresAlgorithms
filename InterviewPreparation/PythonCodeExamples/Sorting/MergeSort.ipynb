# %% [markdown]
# # Merge Sort [Divide and Conquer]

# %%
def merge(arr, left, right):
    i = 0
    j = 0
    
    #k for iterating through Entire List
    k = 0
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            arr[k] = left[i]
            i += 1
        else:
            arr[k] = right[j]
            j += 1
        k += 1
        
    #Still some elements left 
    while i < len(left):
        arr[k] = left[i]
        i += 1
        k += 1
    while j < len(right):
        arr[k] = right[j]
        j += 1
        k += 1
        
    
            

def mergeSort(arr):
    
    #Splitting the array until get the one element at each list
    if len(arr) > 1:
        
        mid = len(arr) // 2  #8/2 = 4
        print("Mid Value is: ", mid)
        left = arr[: mid]     #Here it takes O(n) space for creating 
        print("Left array is : ", left)
        right = arr[mid: ]    #the extra space for sub arrays
        print("Right Array is: ", right)
        
        print("MergeSort Left -----> ")
        print("Mid now Left: ", mid)
        mergeSort(left)       #here dividing happens upto some certain Levels
        print("*" * 100)
        
        print("MergeSort Right -----> ")
        print("Mid Now at Right: ", mid)
        mergeSort(right)      #and that levels depends on log(n)
        print("halfRight Completed")
        print("*" * 100)
        
        #Calling merge function
        print("Merging Starts: ", left, right)
        merge(arr, left, right)   #Merge Takes time complexity of O(n)
        
        print("After Merging array is =====>", arr)
        
 
arr = [54, 26, 93, 17, 77, 31, 44, 55]
print("Before Sorting: ", arr)
mergeSort(arr)
print("After Sorting: ", arr)
# Out:
# Before Sorting:  [54, 26, 93, 17, 77, 31, 44, 55]
# Mid Value is:  4
# Left array is :  [54, 26, 93, 17]
# Right Array is:  [77, 31, 44, 55]
# MergeSort Left ----->
# Mid now Left:  4
# Mid Value is:  2
# Left array is :  [54, 26]
# Right Array is:  [93, 17]
# MergeSort Left ----->
# Mid now Left:  2
# Mid Value is:  1
# Left array is :  [54]
# Right Array is:  [26]
# MergeSort Left ----->
# Mid now Left:  1
# ****************************************************************************************************
# MergeSort Right ----->
# Mid Now at Right:  1
# halfRight Completed
# ****************************************************************************************************
# Merging Starts:  [54] [26]
# After Merging array is =====> [26, 54]
# ****************************************************************************************************
# MergeSort Right ----->
# Mid Now at Right:  2
# Mid Value is:  1
# Left array is :  [93]
# Right Array is:  [17]
# MergeSort Left ----->
# Mid now Left:  1
# ****************************************************************************************************
# MergeSort Right ----->
# Mid Now at Right:  1
# halfRight Completed
# ****************************************************************************************************
# Merging Starts:  [93] [17]
# After Merging array is =====> [17, 93]
# halfRight Completed
# ****************************************************************************************************
# Merging Starts:  [26, 54] [17, 93]
# After Merging array is =====> [17, 26, 54, 93]
# ****************************************************************************************************
# MergeSort Right ----->
# Mid Now at Right:  4
# Mid Value is:  2
# Left array is :  [77, 31]
# Right Array is:  [44, 55]
# MergeSort Left ----->
# Mid now Left:  2
# Mid Value is:  1
# Left array is :  [77]
# Right Array is:  [31]
# MergeSort Left ----->
# Mid now Left:  1
# ****************************************************************************************************
# MergeSort Right ----->
# Mid Now at Right:  1
# halfRight Completed
# ****************************************************************************************************
# Merging Starts:  [77] [31]
# After Merging array is =====> [31, 77]
# ****************************************************************************************************
# MergeSort Right ----->
# Mid Now at Right:  2
# Mid Value is:  1
# Left array is :  [44]
# Right Array is:  [55]
# MergeSort Left ----->
# Mid now Left:  1
# ****************************************************************************************************
# MergeSort Right ----->
# Mid Now at Right:  1
# halfRight Completed
# ****************************************************************************************************
# Merging Starts:  [44] [55]
# After Merging array is =====> [44, 55]
# halfRight Completed
# ****************************************************************************************************
# Merging Starts:  [31, 77] [44, 55]
# After Merging array is =====> [31, 44, 55, 77]
# halfRight Completed
# ****************************************************************************************************
# Merging Starts:  [17, 26, 54, 93] [31, 44, 55, 77]
# After Merging array is =====> [17, 26, 31, 44, 54, 55, 77, 93]
# After Sorting:  [17, 26, 31, 44, 54, 55, 77, 93]

# %%
def merge(arr, left, right):
    i = 0
    j = 0
    
    #k for iterating through Entire List
    k = 0
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            arr[k] = left[i]
            i += 1
        else:
            arr[k] = right[j]
            j += 1
        k += 1
        
    #Still some elements left 
    while i < len(left):
        arr[k] = left[i]
        i += 1
        k += 1
    while j < len(right):
        arr[k] = right[j]
        j += 1
        k += 1
        
    
            

def mergeSort(arr):
    
    #Splitting the array until get the one element at each list
    if len(arr) > 1:
        mid = len(arr) // 2  #8/2 = 4
        left = arr[: mid]     #Here it takes O(n) space for creating 
        right = arr[mid: ]    #the extra space for sub arrays
        mergeSort(left)       #here dividing happens upto some certain Levels
        mergeSort(right)      #and that levels depends on log(n)
        
        #Calling merge function
        merge(arr, left, right)   #Merge Takes time complexity of O(n)
        
 
arr = [54, 26, 93, 17, 77, 31, 44, 55]
print("Before Sorting: ", arr)
mergeSort(arr)
print("After Sorting: ", arr)
# Out:
# Before Sorting:  [54, 26, 93, 17, 77, 31, 44, 55]
# After Sorting:  [17, 26, 31, 44, 54, 55, 77, 93]

# %% [markdown]
# ## TimeComplexity:

# %% [markdown]
# ### Best Case And Worst Case: O(n*log(n))

# %% [markdown]
# - Here 'n' stands for time taking for merging sub-arrays at each sub levels
# - Here 'log(n)' Stands for Number of Levels and it sequence stands like 2, 4, 8, 16 which equals to log(n)

# %% [markdown]
# ## SpaceComplexity

# %% [markdown]
# #### Space is Constant: O(n)
#
# - Here This is Because of extra space created for each Sub-arrays
